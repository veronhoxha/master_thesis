# %% [markdown]
# # Hate crime

# %%
import pandas as pd

# %% [markdown]
# ## Real Dataset - Hate crime

# %%
df_real_dataset = pd.read_csv('./real_datasets/criminal_justice/preproccesed/hate_crime_preproccesed.csv')

# %%
df_real_dataset
# Out:
#         data_year       agency_type_name state_abbr state_name incident_date  \
# 0            1991                   City         AR   Arkansas    1991-07-04
# 1            1991                   City         AR   Arkansas    1991-12-24
# 2            1991                   City         AR   Arkansas    1991-07-10
# 3            1991                   City         AR   Arkansas    1991-10-06
# 4            1991                 County         AR   Arkansas    1991-10-14
# ...           ...                    ...        ...        ...           ...
# 265829       2024                   City         WY    Wyoming    2024-10-18
# 265830       2024                   City         WY    Wyoming    2024-11-11
# 265831       2024                   City         WY    Wyoming    2024-12-12
# 265832       2024  University or College         WY    Wyoming    2024-11-18
# 265833       2024  University or College         WY    Wyoming    2024-11-27
#
# ...

# %%
df_real_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 265834 entries, 0 to 265833
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   data_year                 265834 non-null  int64
#  1   agency_type_name          265834 non-null  object
#  2   state_abbr                265834 non-null  object
#  3   state_name                265834 non-null  object
#  4   incident_date             265834 non-null  object
#  5   adult_victim_count        94429 non-null   float64
#  6   juvenile_victim_count     91644 non-null   float64
#  7   total_offender_count      265834 non-null  int64
#  8   adult_offender_count      81967 non-null   float64
#  9   juvenile_offender_count   81960 non-null   float64
#  10  offender_race             265834 non-null  object
#  11  offender_ethnicity        265834 non-null  object
#  12  victim_count              265834 non-null  int64
# ...

# %%
df_real_dataset.shape
# Out:
# (265834, 20)

# %%
df_real_dataset.describe()
# Out:
#            data_year  adult_victim_count  juvenile_victim_count  \
# count  265834.000000        94429.000000           91644.000000
# mean     2008.447516            0.765866               0.110722
# std        10.152622            1.051430               0.499200
# min      1991.000000            0.000000               0.000000
# 25%      2000.000000            0.000000               0.000000
# 50%      2008.000000            1.000000               0.000000
# 75%      2018.000000            1.000000               0.000000
# max      2024.000000          146.000000              60.000000
#
#        total_offender_count  adult_offender_count  juvenile_offender_count  \
# count         265834.000000          81967.000000             81960.000000
# mean               0.946440              0.641417                 0.137933
# std                1.284311              0.798185                 0.562211
# min                0.000000              0.000000                 0.000000
# ...

# %%
df_real_dataset.isnull().sum()
# Out:
# data_year                        0
# agency_type_name                 0
# state_abbr                       0
# state_name                       0
# incident_date                    0
# adult_victim_count          171405
# juvenile_victim_count       174190
# total_offender_count             0
# adult_offender_count        183867
# juvenile_offender_count     183874
# offender_race                    0
# offender_ethnicity               0
# victim_count                     0
# offense_name                     0
# total_individual_victims      5274
# location_name                    0
# bias_desc                        0
# victim_types                     0
# multiple_offense                 0
# multiple_bias                    0
# dtype: int64

# %% [markdown]
# ## Real Dataset - Hate crime - Zero Shot

# %%
df_zero_shot = pd.read_csv('./generated_datasets/criminal_justice/GPT-5/hate_crime_zero_shot.csv')

# %%
df_zero_shot
# Out:
#      data_year    agency_type_name state_abbr     state_name incident_date  \
# 0         1991                City         GA        Georgia    1991-11-19
# 1         1991              County         SD   South Dakota    1991-11-24
# 2         1991                City         IL       Illinois    1991-02-11
# 3         1991                City         OR         Oregon    1991-06-10
# 4         1991              County         MI       Michigan    1991-07-17
# ..         ...                 ...        ...            ...           ...
# 506       2014               Other         TN      Tennessee    2014-12-16
# 507       2014              County         WV  West Virginia    2014-02-02
# 508       2014                City         MS    Mississippi    2014-04-09
# 509       2014  University/College         MS    Mississippi    2014-01-22
# 510       2014                City         CA     California    2014-03-12
#
# ...

# %%
df_zero_shot.shape
# Out:
# (511, 20)

# %%
df_zero_shot.describe()
# Out:
#          data_year  adult_victim_count  juvenile_victim_count  \
# count   511.000000          511.000000             511.000000
# mean   2002.665362            1.117417               0.140900
# std       6.992962            0.931955               0.370096
# min    1991.000000            0.000000               0.000000
# 25%    1996.000000            0.000000               0.000000
# 50%    2003.000000            1.000000               0.000000
# 75%    2009.000000            2.000000               0.000000
# max    2014.000000            4.000000               2.000000
#
#        total_offender_count  adult_offender_count  juvenile_offender_count  \
# count            511.000000            511.000000               511.000000
# mean               1.248532              0.841487                 0.086106
# std                0.503783              0.743812                 0.280795
# min                1.000000              0.000000                 0.000000
# ...

# %%
df_zero_shot.isnull().sum()
# Out:
# data_year                   0
# agency_type_name            0
# state_abbr                  0
# state_name                  0
# incident_date               0
# adult_victim_count          0
# juvenile_victim_count       0
# total_offender_count        0
# adult_offender_count        0
# juvenile_offender_count     0
# offender_race               0
# offender_ethnicity          0
# victim_count                0
# offense_name                0
# total_individual_victims    0
# location_name               0
# bias_desc                   0
# victim_types                0
# multiple_offense            0
# multiple_bias               0
# dtype: int64

# %% [markdown]
# ## Real Dataset - Hate crime - One Shot

# %%
df_one_shot = pd.read_csv('./generated_datasets/criminal_justice/GPT-5/hate_crime_one_shot.csv')

# %%
df_one_shot.shape
# Out:
# (467, 20)

# %%
df_one_shot.describe
# Out:
# <bound method NDFrame.describe of      data_year    agency_type_name state_abbr   state_name incident_date  \
# 0         1991                City         AR     Arkansas    1991-07-04
# 1         1991                City         DE     Delaware    1991-05-21
# 2         1991              County         HI       Hawaii    1991-06-24
# 3         1991              County         MS  Mississippi    1991-12-27
# 4         1991        State Police         OH         Ohio    1991-03-25
# ..         ...                 ...        ...          ...           ...
# 462       2014                City         CO     Colorado    2014-11-18
# 463       2014              County         LA    Louisiana    2014-03-05
# 464       2014  University/College         VA     Virginia    2014-02-27
# 465       2014              County         MD     Maryland    2014-05-27
# 466       2014  University/College         NM   New Mexico    2014-02-27
#
# ...

# %%
df_one_shot.isnull().sum()
# Out:
# data_year                    0
# agency_type_name             0
# state_abbr                   0
# state_name                   0
# incident_date                0
# adult_victim_count          25
# juvenile_victim_count       27
# total_offender_count        30
# adult_offender_count        35
# juvenile_offender_count     24
# offender_race                0
# offender_ethnicity           0
# victim_count                 0
# offense_name                 0
# total_individual_victims     0
# location_name                0
# bias_desc                    0
# victim_types                 0
# multiple_offense             0
# multiple_bias                0
# dtype: int64

# %% [markdown]
# ## Real Dataset - Hate crime - Few Shot

# %%
df_few_shot = pd.read_csv('./generated_datasets/criminal_justice/GPT-5/hate_crime_few_shot.csv')

# %%
df_few_shot.shape
# Out:
# (539, 20)

# %%
df_few_shot.describe
# Out:
# <bound method NDFrame.describe of      data_year    agency_type_name state_abbr      state_name incident_date  \
# 0         1991                City         AR        Arkansas    1991-07-04
# 1         1991                City         AR        Arkansas    1991-12-24
# 2         1991                City         AR        Arkansas    1991-07-10
# 3         1991                City         AR        Arkansas    1991-10-06
# 4         1991              County         MA   Massachusetts    1991-07-22
# ..         ...                 ...        ...             ...           ...
# 534       2014        State Police         WV   West Virginia    2014-09-11
# 535       2014        State Police         SC  South Carolina    2014-04-16
# 536       2014              County         WV   West Virginia    2014-11-15
# 537       2014                City         MS     Mississippi    2014-01-30
# 538       2014  University/College         MI        Michigan    2014-01-17
#
# ...

# %%
df_few_shot.isnull().sum()
# Out:
# data_year                    0
# agency_type_name             0
# state_abbr                   0
# state_name                   0
# incident_date                0
# adult_victim_count          64
# juvenile_victim_count       57
# total_offender_count        60
# adult_offender_count        62
# juvenile_offender_count     60
# offender_race                0
# offender_ethnicity           0
# victim_count                 0
# offense_name                 0
# total_individual_victims     0
# location_name                0
# bias_desc                    0
# victim_types                 0
# multiple_offense             0
# multiple_bias                0
# dtype: int64
