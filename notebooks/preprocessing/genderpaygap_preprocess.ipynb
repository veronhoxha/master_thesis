# %% [markdown]
# # Employment Dataset Pre-processing (UK Gender Pay Gap)
#
# Dropping columns that we don't use in our experiments.

# %% [markdown]
# ## Imports

# %%
import pandas as pd

# %%
df = pd.read_csv("../../data/raw/uk_gender_pay_gap_data_2024_to_2025.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11239 entries, 0 to 11238
# Data columns (total 27 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   EmployerName               11239 non-null  object
#  1   EmployerId                 11239 non-null  int64
#  2   Address                    11205 non-null  object
#  3   PostCode                   11181 non-null  object
#  4   CompanyNumber              9756 non-null   object
#  5   SicCodes                   10329 non-null  object
#  6   DiffMeanHourlyPercent      11239 non-null  float64
#  7   DiffMedianHourlyPercent    11239 non-null  float64
#  8   DiffMeanBonusPercent       8520 non-null   float64
#  9   DiffMedianBonusPercent     8520 non-null   float64
#  10  MaleBonusPercent           11239 non-null  float64
#  11  FemaleBonusPercent         11239 non-null  float64
#  12  MaleLowerQuartile          11239 non-null  float64
# ...

# %%
df.shape
# Out:
# (11239, 27)

# %%
df.describe
# Out:
# <bound method NDFrame.describe of                                             EmployerName  EmployerId  \
# 0      'PRIFYSGOL ABERYSTWYTH' AND 'ABERYSTWYTH UNIVE...       19070
# 1                   "RED BAND" CHEMICAL COMPANY, LIMITED       16879
# 2                        10 TRINITY SQUARE HOTEL LIMITED       19455
# 3                                           10442565 LTD       19491
# 4                                             1509 GROUP       15320
# ...                                                  ...         ...
# 11234                                    ZSCALER UK LTD.       22454
# 11235                 ZURICH EMPLOYMENT SERVICES LIMITED       14076
# 11236                 ZURICH UK GENERAL SERVICES LIMITED       14078
# 11237                                       ZUTO LIMITED       14080
# 11238                   ZWANENBERG FOOD GROUP UK LIMITED       14081
#
#                                                  Address  PostCode  \
# ...

# %%
df.head()
# Out:
#                                         EmployerName  EmployerId  \
# 0  'PRIFYSGOL ABERYSTWYTH' AND 'ABERYSTWYTH UNIVE...       19070
# 1               "RED BAND" CHEMICAL COMPANY, LIMITED       16879
# 2                    10 TRINITY SQUARE HOTEL LIMITED       19455
# 3                                       10442565 LTD       19491
# 4                                         1509 GROUP       15320
#
#                                              Address  PostCode CompanyNumber  \
# 0  Aberystwyth University, Penglais, Ceredigion, ...  SY23 3FL      RC000641
# 1   19 Smith's Place, Leith Walk, Edinburgh, EH6 8NU   EH6 8NU      SC016876
# 2  5 Market Yard Mews, 194-204 Bermondsey Street,...   SE1 3TQ      08064685
# 3  Compass House 17-19 Empringham Street, Kingsto...   HU9 1RP      10442565
# 4  Royal Grammar School, High Street, Guildford, ...   GU1 3BB      04104101
#
#         SicCodes  DiffMeanHourlyPercent  DiffMedianHourlyPercent  \
# ...

# %%
df.isnull().sum()
# Out:
# EmployerName                    0
# EmployerId                      0
# Address                        34
# PostCode                       58
# CompanyNumber                1483
# SicCodes                      910
# DiffMeanHourlyPercent           0
# DiffMedianHourlyPercent         0
# DiffMeanBonusPercent         2719
# DiffMedianBonusPercent       2719
# MaleBonusPercent                0
# FemaleBonusPercent              0
# MaleLowerQuartile               0
# FemaleLowerQuartile             0
# MaleLowerMiddleQuartile         0
# FemaleLowerMiddleQuartile       0
# MaleUpperMiddleQuartile         0
# FemaleUpperMiddleQuartile       0
# MaleTopQuartile                 0
# FemaleTopQuartile               0
# CompanyLinkToGPGInfo         5182
# ResponsiblePerson            1937
# EmployerSize                    0
# CurrentName                     0
# SubmittedAfterTheDeadline       0
# DueDate                         0
# DateSubmitted                   0
# dtype: int64

# %%
drop_cols = [
    "EmployerId", "Address", "PostCode", "CompanyNumber", 
    "CompanyLinkToGPGInfo", "ResponsiblePerson", "CurrentName", 
    "SubmittedAfterTheDeadline", "DueDate"
]

# %%
df = df.drop(columns=drop_cols, errors="ignore")

# %%
percent_cols = [
    "DiffMeanHourlyPercent", "DiffMedianHourlyPercent",
    "DiffMeanBonusPercent", "DiffMedianBonusPercent",
    "MaleBonusPercent", "FemaleBonusPercent",
    "MaleLowerQuartile", "FemaleLowerQuartile",
    "MaleLowerMiddleQuartile", "FemaleLowerMiddleQuartile",
    "MaleUpperMiddleQuartile", "FemaleUpperMiddleQuartile",
    "MaleTopQuartile", "FemaleTopQuartile"
]

df[percent_cols] = df[percent_cols].apply(pd.to_numeric, errors="coerce")

# %%
df = df.replace(["", "NULL", "NaN", "NA"], pd.NA)

# %%
df["EmployerSize"] = df["EmployerSize"].str.replace(" to ", "-", regex=False)

# %%
df["DateSubmitted"] = pd.to_datetime(df["DateSubmitted"], errors="coerce")

# %%
df.to_csv("../../data/preprocessed/uk_gender_pay_gap_data_2024_to_2025_preproccesed.csv", index=False)

# %%
df_preprocessed = pd.read_csv("../../data/preprocessed/uk_gender_pay_gap_data_2024_to_2025_preproccesed.csv")

# %%
df_preprocessed
# Out:
#                                             EmployerName       SicCodes  \
# 0      'PRIFYSGOL ABERYSTWYTH' AND 'ABERYSTWYTH UNIVE...            NaN
# 1                   "RED BAND" CHEMICAL COMPANY, LIMITED          47730
# 2                        10 TRINITY SQUARE HOTEL LIMITED          82990
# 3                                           10442565 LTD          70229
# 4                                             1509 GROUP  85200,\n85310
# ...                                                  ...            ...
# 11234                                    ZSCALER UK LTD.          62090
# 11235                 ZURICH EMPLOYMENT SERVICES LIMITED  78300,\n82990
# 11236                 ZURICH UK GENERAL SERVICES LIMITED          82990
# 11237                                       ZUTO LIMITED          64999
# 11238                   ZWANENBERG FOOD GROUP UK LIMITED  10110,\n10130
#
#        DiffMeanHourlyPercent  DiffMedianHourlyPercent  DiffMeanBonusPercent  \
# ...
