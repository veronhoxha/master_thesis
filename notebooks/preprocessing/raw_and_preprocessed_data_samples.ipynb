# %%
import pandas as pd

# %%
def sample_large_csv(path, sample_size=200, out_path="sample.csv", chunksize=100000):
    sample_list = []

    # reading the dataset in chunks
    for chunk in pd.read_csv(path, chunksize=chunksize):
        sample_list.append(chunk.sample(n=min(sample_size, len(chunk))))

    # combine samples from all chunks
    sample_df = pd.concat(sample_list).sample(n=sample_size)
    sample_df.to_csv(out_path, index=False)
    print(f"Sample saved: {out_path}")

# %%
datasets_raw = {
    "hate_crime": "../../data/raw/hate_crime.csv",
    "gender_pay_gap": "../../data/raw/uk_gender_pay_gap_data_2024_to_2025.csv",
    "lending": "../../data/raw/year_2024.csv"  # 4GB+, using chunk sampling
}

datasets_pre = {
    "hate_crime": "../../data/preprocessed/hate_crime_preprocessed.csv",
    "gender_pay_gap": "../../data/preprocessed/uk_gender_pay_gap_data_2024_to_2025_preproccesed.csv",
    "lending": "../../data/preprocessed/year_2024_preprocessed.csv"
}

# %%
def make_samples(datasets, folder="raw"):
    for name, path in datasets.items():
        out_path = f"../../data/{folder}/sample_{name}.csv"
        try:
            if name == "lending":
                sample_large_csv(path, sample_size=200, out_path=out_path)
            else:
                df = pd.read_csv(path)
                sample = df.sample(n=200)
                sample.to_csv(out_path, index=False)
                print(f"Sample saved: {out_path}")
        except Exception as e:
            print(f"Could not process {name} in {folder}: {e}")

# %%
make_samples(datasets_raw, folder="raw")
make_samples(datasets_pre, folder="preprocessed")
# Out:
# Sample saved: ../../data/raw/sample_hate_crime.csv
# Sample saved: ../../data/raw/sample_gender_pay_gap.csv
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,32,33,38,43,44) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,32,33,38,43,44) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,32,33,38,43,44) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,32,33,38,43,44) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (24,28) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,32,33,38,43,44) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (43) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,32,33,38,43,44) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,32,33,38,43,44) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (5,22,23,24,26,27,28,29,30,31,32,33,38,43,44) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,32,33,38,43,44) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,32,33,38,43,44) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,32,33,38,43,44) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,32,33,38,43,44) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (43) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,32,33,38,43,44) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,32,33,38,43,44) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,32,33,38,43,44) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (28,29,30,32,33,43,44,46) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,32,33,38,43,44,46) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,32,33,38,43,44) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,32,33,38,43,44) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,32,33,38,43,44) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,32,33,38,43,44) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,32,33,38,43,44) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,32,33,38,43,44) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,32,33,38,43,44) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,32,33,38,43,44) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,32,33,38,43,44) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,32,33,38,43,44) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,32,33,38,43,44) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,32,33,38,43,44) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (43,78,80) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,32,33,38,43,44) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (46) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (43,46) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,32,33,38,43,44) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (43,78,80) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (43) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,32,33,38,43,44) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (43) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,32,33,38,43,44) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,32,33,38,43,44) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (43) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,32,33,38,44) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,32,33,38,43,44) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,32,33,38,43,44) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,32,33,38,43,44) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,32,33,38,43,44,46,77,78,79,80) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,32,33,38,43,44) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (43) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,32,33,38,43,44) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,32,33,38,43,44) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,32,33,38,43,44) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,32,33,38,43,44) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (43) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (43) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,32,33,38,43,44) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,32,33,38,43,44) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,32,33,38,43,44) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (43) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (43) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (43,46,77,78,79,80) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (43) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,32,33,38,43,44) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (43) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (43,46,77,78,79,80) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,32,33,38,43,44) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,32,33,38,43,44) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,32,33,38,43,44,46,77,78,79,80) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,32,33,38,43,44) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,32,33,38,43,44) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,32,33,38,43,44,46,77,78,79,80) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,32,33,38,43,44,46,77,78,79,80) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,32,33,38,43,44,46,77,78,79,80) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (24,43) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,32,33,38,43,44) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,32,33,38,43,44) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,32,33,38,43,44) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,32,33,38,43,44) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (43) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (43) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,32,33,38,43,44) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (43,46) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (43) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (43) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,32,33,38,43,44) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,32,33,38,43,44,46,77,78,79,80) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,32,33,38,43,44,46,77,78,79,80) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,32,33,38,43,44) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,32,33,38,43,44) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (43) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (43,46,77,78,79,80) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (43) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,32,33,38,43,44) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,32,33,38,43,44) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,32,33,38,43,44) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,32,33,38,43,44) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,32,33,38,43,44) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,32,33,38,43,44) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,32,33,38,43,44) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,32,33,38,43,44,46,77,78,79,80) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,32,33,38,43,44) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,32,33,38,43,44) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,32,33,38,43,44) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,32,33,38,43,44) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# Sample saved: ../../data/raw/sample_lending.csv
# Sample saved: ../../data/preprocessed/sample_hate_crime.csv
# Sample saved: ../../data/preprocessed/sample_gender_pay_gap.csv
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (15,17,18,19,20,21,22,23,24,34,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (15,17,18,19,20,21,22,23,24,34,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (15,17,18,19,20,21,22,23,24,34,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (15,17,18,19,20,21,22,23,24,34,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (15,19) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (15,17,18,19,20,21,22,23,24,34,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (34) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (15,17,18,19,20,21,22,23,24,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (15,17,18,19,20,21,22,23,24,34,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (4,15,17,18,19,20,21,22,23,24,34,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (15,17,18,19,20,21,22,23,24,34,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (15,17,18,19,20,21,22,23,24,34,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (15,17,18,19,20,21,22,23,24,34,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (15,17,18,19,20,21,22,23,24,34,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (34) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (10,15,17,18,19,20,21,22,23,24,34,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (15,17,18,19,20,21,22,23,24,34,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (15,17,18,19,20,21,22,23,24,34,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (19,20,21,23,24,34,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (15,22,23,24,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (15,17,18,19,20,21,22,23,24,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (15,17,18,19,20,21,22,23,24,34,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (15,17,18,19,20,21,22,23,24,34,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (15,17,18,19,20,21,22,23,24,34,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (15,17,18,19,20,21,22,23,24,34,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (15,17,18,19,20,21,22,23,24,34,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (15,17,18,19,20,21,22,23,24,34,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (15,17,18,19,20,21,22,23,24,34,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (15,17,18,19,20,21,22,23,24,34,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (15,17,18,19,20,21,22,23,24,34,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (15,17,18,19,20,21,22,23,24,34,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (15,17,18,19,20,21,22,23,24,34,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (34,53,55) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (15,17,18,19,20,21,22,23,24,34,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (34) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (15,17,18,19,20,21,22,23,24,34,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (53,55) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (34) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (15,17,18,19,20,21,22,23,24,34,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (34) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (15,17,18,19,20,21,22,23,24,34,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (15,17,18,19,20,21,22,23,24,34,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (34) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (15,17,18,19,20,21,22,23,24,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (15,17,18,19,20,21,22,23,24,34,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (15,17,18,19,20,21,22,23,24,34,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (15,17,18,19,20,21,22,23,24,34,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (15,17,18,19,20,21,22,23,24,34,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (15,17,18,19,20,21,22,23,24,34,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (34) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (15,17,18,19,20,21,22,23,24,34,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (15,17,18,19,20,21,22,23,24,34,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (15,17,18,19,20,21,22,23,24,34,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (15,17,18,19,20,21,22,23,24,34,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (34) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (34) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (15,17,18,19,20,21,22,23,24,34,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (15,17,18,19,20,21,22,23,24,34,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (15,17,18,19,20,21,22,23,24,34,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (34) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (34) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (34,53,55) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (34) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (15,17,18,19,20,21,22,23,24,34,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (34) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (10,34,52,53,54,55) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (15,17,18,19,20,21,22,23,24,34,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (15,17,18,19,20,21,22,23,24,34,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (10,15,17,18,19,20,21,22,23,24,34,35,52,53,54,55) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (15,17,18,19,20,21,22,23,24,34,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (15,17,18,19,20,21,22,23,24,34,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (10,15,17,18,19,20,21,22,23,24,34,35,52,53,54,55) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (10,15,17,18,19,20,21,22,23,24,34,35,52,53,54,55) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (15,17,18,19,20,21,22,23,24,34,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (15,34) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (15,17,18,19,20,21,22,23,24,34,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (15,17,18,19,20,21,22,23,24,34,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (15,17,18,19,20,21,22,23,24,34,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (15,17,18,19,20,21,22,23,24,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (34) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (34) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (15,17,18,19,20,21,22,23,24,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (34) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (34) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (34) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (15,17,18,19,20,21,22,23,24,34,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (10,15,17,18,19,20,21,22,23,24,34,35,52,53,54,55) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (10,15,17,18,19,20,21,22,23,24,34,35,52,53,54,55) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (15,17,18,19,20,21,22,23,24,34,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (15,17,18,19,20,21,22,23,24,34,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (34) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (34) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (34) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (15,17,18,19,20,21,22,23,24,34,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (15,17,18,19,20,21,22,23,24,34,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (15,17,18,19,20,21,22,23,24,34,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (15,17,18,19,20,21,22,23,24,34,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (15,17,18,19,20,21,22,23,24,34,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (15,17,18,19,20,21,22,23,24,34,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (15,17,18,19,20,21,22,23,24,34,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (15,17,18,19,20,21,22,23,24,34,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (15,17,18,19,20,21,22,23,24,34,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (15,17,18,19,20,21,22,23,24,34,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_2629/3726828889.py:5: DtypeWarning: Columns (15,17,18,19,20,21,22,23,24,34,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(path, chunksize=chunksize):
# Sample saved: ../../data/preprocessed/sample_lending.csv
