# %%
import pandas as pd

# %%
df = pd.read_csv("../../data/raw/year_2024.csv")
# Out:
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_1412/3419199480.py:1: DtypeWarning: Columns (5,22,23,24,26,27,28,29,30,31,32,33,38,43,44,46,77,78,79,80) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("../../data/raw/year_2024.csv")

# %%
df.head()
# Out:
#    activity_year                   lei  derived_msa-md state_code  \
# 0           2024  549300DD5QQUHO6PCH70           38060         AZ
# 1           2024  549300DD5QQUHO6PCH70           24780         NC
# 2           2024  549300DD5QQUHO6PCH70           29414         IN
# 3           2024  549300DD5QQUHO6PCH70           17900         SC
# 4           2024  549300DD5QQUHO6PCH70           36420         OK
#
#    county_code   census_tract conforming_loan_limit derived_loan_product_type  \
# 0       4013.0   4013061031.0                     C             VA:First Lien
# 1      37147.0  37147001100.0                     C             VA:First Lien
# 2      18127.0  18127050602.0                     C             VA:First Lien
# 3      45063.0  45063020706.0                     C   Conventional:First Lien
# 4      40081.0  40081961402.0                     C             VA:First Lien
#
#               derived_dwelling_category        derived_ethnicity  ...  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12229298 entries, 0 to 12229297
# Data columns (total 99 columns):
#  #   Column                                    Dtype
# ---  ------                                    -----
#  0   activity_year                             int64
#  1   lei                                       object
#  2   derived_msa-md                            int64
#  3   state_code                                object
#  4   county_code                               float64
#  5   census_tract                              object
#  6   conforming_loan_limit                     object
#  7   derived_loan_product_type                 object
#  8   derived_dwelling_category                 object
#  9   derived_ethnicity                         object
#  10  derived_race                              object
#  11  derived_sex                               object
#  12  action_taken                              int64
# ...

# %%
drop_cols = [
    "lei", "conforming_loan_limit", "purchaser_type", "preapproval", 
    "loan_type", "lien_status", "reverse_mortgage", 
    "open-end_line_of_credit", "business_or_commercial_purpose", 
    "applicant_ethnicity-2", "applicant_ethnicity-3", "applicant_ethnicity-4", "applicant_ethnicity-5",
    "co-applicant_ethnicity-2", "co-applicant_ethnicity-3", "co-applicant_ethnicity-4", "co-applicant_ethnicity-5",
    "applicant_race-2", "applicant_race-3", "applicant_race-4", "applicant_race-5",
    "co-applicant_race-2", "co-applicant_race-3", "co-applicant_race-4", "co-applicant_race-5",
    "aus-1","aus-2","aus-3","aus-4","aus-5",
    "denial_reason-1","denial_reason-2","denial_reason-3","denial_reason-4",
    "tract_population","tract_minority_population_percent","ffiec_msa_md_median_family_income",
    "tract_to_msa_income_percentage","tract_owner_occupied_units","tract_one_to_four_family_homes",
    "tract_median_age_of_housing_units"
]

# %%
df = df.drop(columns=drop_cols, errors="ignore")

# %%
df = df.replace(["", "NULL", "NaN", "NA"], pd.NA)

# %%
num_cols = ["loan_amount", "loan_to_value_ratio", "interest_rate", "property_value", "income", "debt_to_income_ratio"]
for col in num_cols:
    df[col] = pd.to_numeric(df[col], errors="coerce")

# %%
action_map = {
    1: "Loan originated",
    2: "Application approved but not accepted",
    3: "Application denied",
    4: "Application withdrawn",
    5: "File closed for incompleteness"
}
df["action_taken"] = df["action_taken"].map(action_map).fillna(df["action_taken"])

# %%
df.to_csv("../../data/preprocessed/year_2024_preprocessed.csv", index=False)

# %%
df_cleaned = pd.read_csv("../../data/preprocessed/year_2024_preprocessed.csv")
# Out:
# /var/folders/26/qp1p5b3149b9hy747yzmh3bh0000gn/T/ipykernel_1412/596415016.py:1: DtypeWarning: Columns (4,10,15,17,18,19,20,21,22,23,24,34,35,52,53,54,55) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_cleaned = pd.read_csv("../../data/preprocessed/year_2024_preprocessed.csv")

# %%
df_cleaned
# Out:
#           activity_year  derived_msa-md state_code  county_code  \
# 0                  2024           38060         AZ       4013.0
# 1                  2024           24780         NC      37147.0
# 2                  2024           29414         IN      18127.0
# 3                  2024           17900         SC      45063.0
# 4                  2024           36420         OK      40081.0
# ...                 ...             ...        ...          ...
# 12229293           2024           40420         IL      17201.0
# 12229294           2024           48680         FL      12119.0
# 12229295           2024           99999         MS      28109.0
# 12229296           2024           19340         IA      19163.0
# 12229297           2024           18140         OH      39049.0
#
#            census_tract derived_loan_product_type  \
# 0          4013061031.0             VA:First Lien
# 1         37147001100.0             VA:First Lien
# ...

# %%
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12229298 entries, 0 to 12229297
# Data columns (total 58 columns):
#  #   Column                                    Dtype
# ---  ------                                    -----
#  0   activity_year                             int64
#  1   derived_msa-md                            int64
#  2   state_code                                object
#  3   county_code                               float64
#  4   census_tract                              object
#  5   derived_loan_product_type                 object
#  6   derived_dwelling_category                 object
#  7   derived_ethnicity                         object
#  8   derived_race                              object
#  9   derived_sex                               object
#  10  action_taken                              object
#  11  loan_purpose                              int64
#  12  loan_amount                               float64
# ...
