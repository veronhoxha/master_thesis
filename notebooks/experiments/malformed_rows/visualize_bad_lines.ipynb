# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

from visualize_bad_lines import *

# WARNINGS
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning, module="pkg_resources")

# %%
PROJECT_ROOT = find_project_root()

# %%
df = pd.read_csv(PROJECT_ROOT / "analysis" / "bad_lines" / "bad_lines_by_llm_domain_shot.csv")

# %%
plot_faceted_by_llm(df)
# Out:
# ================================================================================
# SUMMARY: Total Bad Lines Found Per LLM
# ================================================================================
# kimi-k2-instruct-0905: 1,519 bad rows (12.7% of all bad lines, 5.47% of 27,773 generated rows)
# llama-3.1-8b-instruct: 6,180 bad rows (51.6% of all bad lines, 21.55% of 28,681 generated rows)
# qwen3-coder-30b-a3b-instruct: 4,289 bad rows (35.8% of all bad lines, 15.44% of 27,781 generated rows)
#
# Total bad lines across all LLMs: 11988
#
# ================================================================================
# AVERAGE BAD ROWS PER LLM (MEAN PER RUN ACROSS ALL DOMAINS)
# ================================================================================
#                          llm avg_bad_rows_per_run std_bad_rows_per_run min_bad_rows_per_run max_bad_rows_per_run num_runs
#        llama-3.1-8b-instruct             2,060.00               272.51                1,749                2,257        3
# qwen3-coder-30b-a3b-instruct             1,429.67               251.46                1,281                1,720        3
#        kimi-k2-instruct-0905               506.33               200.16                  293                  690        3
#
# ================================================================================
# AVERAGE BAD ROWS PER LLM BY DOMAIN
# ================================================================================
#
# llama-3.1-8b-instruct:
#     domain avg_bad_rows_per_run
# employment               232.67
#  hatecrime             1,484.33
#    lending               343.00
#
# qwen3-coder-30b-a3b-instruct:
#    domain avg_bad_rows_per_run
# hatecrime                78.00
#   lending             1,351.67
#
# kimi-k2-instruct-0905:
#     domain avg_bad_rows_per_run
# employment                37.67
#  hatecrime                 1.67
#    lending               467.00
#
# ================================================================================
# AVERAGE BAD ROWS PER LLM BY SHOT
# ================================================================================
#
# llama-3.1-8b-instruct:
# shot avg_bad_rows_per_run
#  few               813.00
#  one               710.67
# zero               536.33
#
# qwen3-coder-30b-a3b-instruct:
# shot avg_bad_rows_per_run
#  few               451.67
#  one               574.00
# zero               404.00
#
# kimi-k2-instruct-0905:
# shot avg_bad_rows_per_run
#  few               328.33
#  one                21.00
# zero               157.00
#
# ================================================================================
# AVERAGE BAD ROWS PER LLM BY DOMAIN AND SHOT
# ================================================================================
#
# llama-3.1-8b-instruct:
#     domain shot avg_bad_rows_per_run
# employment zero               121.67
# employment  one                58.33
# employment  few                52.67
#  hatecrime zero               293.00
#  hatecrime  one               467.00
#  hatecrime  few               724.33
#    lending zero               121.67
#    lending  one               185.33
#    lending  few                36.00
#
# qwen3-coder-30b-a3b-instruct:
#    domain shot avg_bad_rows_per_run
# hatecrime zero                43.00
# hatecrime  one                26.33
# hatecrime  few                 8.67
#   lending zero               361.00
#   lending  one               547.67
#   lending  few               443.00
#
# kimi-k2-instruct-0905:
#     domain shot avg_bad_rows_per_run
# employment zero                24.33
# employment  one                11.67
# employment  few                 1.67
#  hatecrime  one                 1.67
#    lending zero               132.67
#    lending  one                 7.67
#    lending  few               326.67
# ================================================================================
